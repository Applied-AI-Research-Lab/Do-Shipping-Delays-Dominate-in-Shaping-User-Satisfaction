# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# Set base path for the project
base_path = '/content/gdrive/My Drive/Projects/CustomerSatisfactionLogistics/'

# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import ParameterGrid
import json
from datetime import datetime
import os


def configure_gpu():
    """Configure GPU settings"""
    if tf.config.list_physical_devices('GPU'):
        for gpu in tf.config.list_physical_devices('GPU'):
            tf.config.experimental.set_memory_growth(gpu, True)
        tf.keras.mixed_precision.set_global_policy('mixed_float16')
        return True
    return False

def prepare_single_feature_data(train_df, val_df, test_df, feature_name):
    """Prepare datasets with single feature"""
    scaler = StandardScaler()

    # Extract feature and target
    X_train = train_df[[feature_name]]
    X_val = val_df[[feature_name]]
    X_test = test_df[[feature_name]]

    # Scale the feature
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    # Prepare targets (adjust to 0-4 range)
    y_train = train_df['Customer_Rating'] - 1
    y_val = val_df['Customer_Rating'] - 1
    y_test = test_df['Customer_Rating'] - 1

    return X_train_scaled, X_val_scaled, X_test_scaled, y_train, y_val, y_test

def create_model(input_dim, params):
    """Create neural network model"""
    model = models.Sequential([
        layers.Dense(params['units'], activation=params['activation'], input_dim=input_dim),
        layers.BatchNormalization(),
        layers.Dropout(params['dropout']),
        layers.Dense(params['units'] // 2, activation=params['activation']),
        layers.BatchNormalization(),
        layers.Dropout(params['dropout']),
        layers.Dense(5, activation='softmax')
    ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(optimizer=optimizer,
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])
    return model

def grid_search_single_feature(feature_name, X_train, X_val, X_test, y_train, y_val, y_test):
    """Perform grid search for single feature"""
    # Parameter grid
    param_grid = {
        'units': [16, 32, 64, 128],
        'activation': ['relu', 'elu', 'tanh'],
        'dropout': [0.1, 0.2, 0.3, 0.4],
        'learning_rate': [0.1, 0.01, 0.001],
        'batch_size': [32, 64, 128]
    }

    # Generate 100 random combinations
    all_combinations = list(ParameterGrid(param_grid))
    np.random.shuffle(all_combinations)
    param_combinations = all_combinations[:100]

    results = []
    best_accuracy = 0
    best_params = None

    print(f"\nTraining models for feature: {feature_name}")
    print(f"Number of parameter combinations: {len(param_combinations)}")

    for i, params in enumerate(param_combinations, 1):
        print(f"\nCombination {i}/100")
        print(f"Parameters: {params}")

        model = create_model(X_train.shape[1], params)

        # Early stopping
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        # Train model
        history = model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=30,
            batch_size=params['batch_size'],
            callbacks=[early_stopping],
            verbose=0
        )

        # Evaluate model
        train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
        val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)
        test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

        result = {
            'feature': feature_name,
            'params': params,
            'train_accuracy': float(train_acc),
            'val_accuracy': float(val_acc),
            'test_accuracy': float(test_acc),
            'train_loss': float(train_loss),
            'val_loss': float(val_loss),
            'test_loss': float(test_loss),
            'epochs_trained': len(history.history['loss'])
        }

        results.append(result)

        if val_acc > best_accuracy:
            best_accuracy = val_acc
            best_params = params

        print(f"Train Accuracy: {train_acc:.4f}")
        print(f"Validation Accuracy: {val_acc:.4f}")
        print(f"Test Accuracy: {test_acc:.4f}")

    return results, best_params

def run_feature_importance_validation(base_path):
    """Run the complete feature importance validation experiment"""
    # Configure GPU
    configure_gpu()

    # Create results directory within the project folder
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    results_dir = os.path.join(base_path, f"feature_validation_results_{timestamp}")
    os.makedirs(results_dir, exist_ok=True)

    # Load data from Google Drive
    train_df = pd.read_csv(os.path.join(base_path, 'train_set.csv'))
    val_df = pd.read_csv(os.path.join(base_path, 'validation_set.csv'))
    test_df = pd.read_csv(os.path.join(base_path, 'test_set.csv'))

    # Features to validate
    features = ['Reached_on_Time', 'Cost_of_the_Product', 'Customer_Care_Calls']

    all_results = {}
    feature_summaries = {}

    for feature in features:
        print(f"\nValidating feature: {feature}")

        # Prepare data
        X_train, X_val, X_test, y_train, y_val, y_test = prepare_single_feature_data(
            train_df, val_df, test_df, feature
        )

        # Perform grid search
        results, best_params = grid_search_single_feature(
            feature, X_train, X_val, X_test, y_train, y_val, y_test
        )

        # Store results
        all_results[feature] = results

        # Calculate summary statistics
        val_accuracies = [r['val_accuracy'] for r in results]
        feature_summaries[feature] = {
            'mean_val_accuracy': np.mean(val_accuracies),
            'max_val_accuracy': np.max(val_accuracies),
            'min_val_accuracy': np.min(val_accuracies),
            'std_val_accuracy': np.std(val_accuracies),
            'best_params': best_params
        }

        # Save individual feature results to Google Drive
        feature_df = pd.DataFrame(results)
        feature_df.to_csv(os.path.join(results_dir, f"{feature}_results.csv"), index=False)

    # Save summary results to Google Drive
    with open(os.path.join(results_dir, "feature_summaries.json"), 'w') as f:
        json.dump(feature_summaries, f, indent=4)

    # Create comparison DataFrame
    comparison_data = []
    for feature, summary in feature_summaries.items():
        comparison_data.append({
            'Feature': feature,
            'Mean Validation Accuracy': summary['mean_val_accuracy'],
            'Max Validation Accuracy': summary['max_val_accuracy'],
            'Min Validation Accuracy': summary['min_val_accuracy'],
            'Std Validation Accuracy': summary['std_val_accuracy']
        })

    comparison_df = pd.DataFrame(comparison_data)
    comparison_df.to_csv(os.path.join(results_dir, "feature_comparison.csv"), index=False)

    print("\nExperiment completed!")
    print(f"Results saved in directory: {results_dir}")
    print("\nFeature Comparison Summary:")
    print(comparison_df)

    return all_results, feature_summaries, comparison_df

if __name__ == "__main__":
    # Run the validation with the Google Drive path
    all_results, feature_summaries, comparison_df = run_feature_importance_validation(base_path)
# Out:
# Mounted at /content/gdrive
#
# Validating feature: Reached_on_Time
#
# Training models for feature: Reached_on_Time
# Number of parameter combinations: 100
#
# Combination 1/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 2/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.1996
# Test Accuracy: 0.1966
#
# Combination 3/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.1996
# Test Accuracy: 0.1966
#
# Combination 4/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 5/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 6/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 7/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 8/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2015
# Validation Accuracy: 0.1889
# Test Accuracy: 0.2091
#
# Combination 9/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 10/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 11/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2062
#
# Combination 12/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 13/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 14/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 15/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 16/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.1980
# Validation Accuracy: 0.2010
# Test Accuracy: 0.2057
#
# Combination 17/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.1939
# Validation Accuracy: 0.2173
# Test Accuracy: 0.2062
#
# Combination 18/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 19/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 20/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 21/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 22/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 23/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.1873
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2040
#
# Combination 24/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 25/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 26/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.1980
# Validation Accuracy: 0.2010
# Test Accuracy: 0.2057
#
# Combination 27/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 28/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 29/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1939
# Validation Accuracy: 0.2173
# Test Accuracy: 0.2062
#
# Combination 30/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 31/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 32/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1835
#
# Combination 33/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.1911
# Test Accuracy: 0.1994
#
# Combination 34/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 35/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2062
#
# Combination 36/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 37/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1966
# Validation Accuracy: 0.1953
# Test Accuracy: 0.2051
#
# Combination 38/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 39/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 40/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1835
#
# Combination 41/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 42/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 43/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.1969
# Validation Accuracy: 0.2010
# Test Accuracy: 0.2091
#
# Combination 44/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 45/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 46/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 47/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 48/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 49/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 50/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 51/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2062
#
# Combination 52/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 53/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 54/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 55/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 56/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 57/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 58/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 59/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 60/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2008
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1966
#
# Combination 61/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.1996
# Test Accuracy: 0.1966
#
# Combination 62/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 63/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.1996
# Test Accuracy: 0.1966
#
# Combination 64/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 65/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 66/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 67/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 68/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.1969
# Validation Accuracy: 0.2010
# Test Accuracy: 0.2091
#
# Combination 69/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 70/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 71/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 72/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 73/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 74/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 75/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.1941
# Validation Accuracy: 0.1868
# Test Accuracy: 0.2045
#
# Combination 76/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 77/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 78/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 79/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 80/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1841
#
# Combination 81/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 82/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 83/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1835
#
# Combination 84/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 85/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2102
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1881
#
# Combination 86/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 87/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2062
#
# Combination 88/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2008
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1966
#
# Combination 89/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1969
# Validation Accuracy: 0.2010
# Test Accuracy: 0.2091
#
# Combination 90/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 91/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1985
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2062
#
# Combination 92/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1835
#
# Combination 93/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 94/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 95/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2062
#
# Combination 96/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.1914
# Validation Accuracy: 0.2088
# Test Accuracy: 0.2057
#
# Combination 97/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1852
#
# Combination 98/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 99/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 100/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Validating feature: Cost_of_the_Product
#
# Training models for feature: Cost_of_the_Product
# Number of parameter combinations: 100
#
# Combination 1/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Accuracy: 0.2168
# Validation Accuracy: 0.2152
# Test Accuracy: 0.1937
#
# Combination 2/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2054
# Validation Accuracy: 0.2116
# Test Accuracy: 0.2153
#
# Combination 3/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2028
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1903
#
# Combination 4/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2138
# Test Accuracy: 0.1903
#
# Combination 5/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.1926
# Validation Accuracy: 0.1974
# Test Accuracy: 0.1920
#
# Combination 6/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2156
# Validation Accuracy: 0.2180
# Test Accuracy: 0.1892
#
# Combination 7/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2017
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1932
#
# Combination 8/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 9/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2028
# Validation Accuracy: 0.2209
# Test Accuracy: 0.1898
#
# Combination 10/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2134
# Validation Accuracy: 0.2031
# Test Accuracy: 0.1869
#
# Combination 11/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.2038
# Test Accuracy: 0.2011
#
# Combination 12/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2033
# Validation Accuracy: 0.2010
# Test Accuracy: 0.1813
#
# Combination 13/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 14/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2145
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1909
#
# Combination 15/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 16/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2061
# Validation Accuracy: 0.2116
# Test Accuracy: 0.1966
#
# Combination 17/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 18/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2143
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1790
#
# Combination 19/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2028
# Validation Accuracy: 0.2337
# Test Accuracy: 0.1852
#
# Combination 20/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2118
# Validation Accuracy: 0.2031
# Test Accuracy: 0.1972
#
# Combination 21/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2088
# Validation Accuracy: 0.2102
# Test Accuracy: 0.2011
#
# Combination 22/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2013
# Validation Accuracy: 0.2017
# Test Accuracy: 0.2108
#
# Combination 23/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2116
# Validation Accuracy: 0.2138
# Test Accuracy: 0.2000
#
# Combination 24/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1987
# Validation Accuracy: 0.1974
# Test Accuracy: 0.2119
#
# Combination 25/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2069
# Validation Accuracy: 0.2209
# Test Accuracy: 0.2114
#
# Combination 26/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2067
# Validation Accuracy: 0.2244
# Test Accuracy: 0.1830
#
# Combination 27/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2193
# Validation Accuracy: 0.2202
# Test Accuracy: 0.1852
#
# Combination 28/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.2038
# Test Accuracy: 0.2040
#
# Combination 29/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2054
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1818
#
# Combination 30/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2085
# Validation Accuracy: 0.2081
# Test Accuracy: 0.1932
#
# Combination 31/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2086
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1852
#
# Combination 32/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2026
# Validation Accuracy: 0.1918
# Test Accuracy: 0.2244
#
# Combination 33/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2010
# Validation Accuracy: 0.2209
# Test Accuracy: 0.1932
#
# Combination 34/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2003
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1977
#
# Combination 35/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 36/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 37/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 38/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 39/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2060
# Validation Accuracy: 0.2202
# Test Accuracy: 0.1977
#
# Combination 40/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.1987
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1909
#
# Combination 41/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2127
# Validation Accuracy: 0.2152
# Test Accuracy: 0.1926
#
# Combination 42/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2083
# Validation Accuracy: 0.2173
# Test Accuracy: 0.2062
#
# Combination 43/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 44/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 45/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.1957
# Validation Accuracy: 0.1911
# Test Accuracy: 0.2051
#
# Combination 46/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 47/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2042
# Validation Accuracy: 0.2180
# Test Accuracy: 0.1898
#
# Combination 48/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2026
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1920
#
# Combination 49/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2076
# Validation Accuracy: 0.2180
# Test Accuracy: 0.2153
#
# Combination 50/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1946
# Test Accuracy: 0.1983
#
# Combination 51/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 52/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2134
# Validation Accuracy: 0.2024
# Test Accuracy: 0.2000
#
# Combination 53/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2120
# Validation Accuracy: 0.2216
# Test Accuracy: 0.1932
#
# Combination 54/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1994
# Validation Accuracy: 0.2038
# Test Accuracy: 0.2034
#
# Combination 55/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2156
# Validation Accuracy: 0.2067
# Test Accuracy: 0.1932
#
# Combination 56/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2109
# Validation Accuracy: 0.2145
# Test Accuracy: 0.2142
#
# Combination 57/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2013
# Validation Accuracy: 0.2266
# Test Accuracy: 0.1932
#
# Combination 58/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2015
# Validation Accuracy: 0.1996
# Test Accuracy: 0.2011
#
# Combination 59/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2106
# Validation Accuracy: 0.2067
# Test Accuracy: 0.2085
#
# Combination 60/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.1996
# Validation Accuracy: 0.2166
# Test Accuracy: 0.1886
#
# Combination 61/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2065
# Validation Accuracy: 0.2237
# Test Accuracy: 0.2182
#
# Combination 62/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2111
# Validation Accuracy: 0.2237
# Test Accuracy: 0.2023
#
# Combination 63/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2159
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1858
#
# Combination 64/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2047
# Validation Accuracy: 0.2237
# Test Accuracy: 0.1972
#
# Combination 65/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1989
# Validation Accuracy: 0.1875
# Test Accuracy: 0.1869
#
# Combination 66/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2127
# Validation Accuracy: 0.2109
# Test Accuracy: 0.2017
#
# Combination 67/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2077
# Validation Accuracy: 0.2152
# Test Accuracy: 0.2148
#
# Combination 68/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2070
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1994
#
# Combination 69/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.1989
# Test Accuracy: 0.2153
#
# Combination 70/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2083
# Validation Accuracy: 0.2038
# Test Accuracy: 0.2023
#
# Combination 71/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.1839
# Test Accuracy: 0.2045
#
# Combination 72/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1881
#
# Combination 73/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2003
# Validation Accuracy: 0.2173
# Test Accuracy: 0.2051
#
# Combination 74/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2015
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1977
#
# Combination 75/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2150
# Validation Accuracy: 0.2038
# Test Accuracy: 0.1875
#
# Combination 76/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 77/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 78/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1989
# Validation Accuracy: 0.2138
# Test Accuracy: 0.2006
#
# Combination 79/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2054
# Validation Accuracy: 0.2116
# Test Accuracy: 0.1892
#
# Combination 80/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2053
# Validation Accuracy: 0.2109
# Test Accuracy: 0.2000
#
# Combination 81/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2056
# Validation Accuracy: 0.2180
# Test Accuracy: 0.1983
#
# Combination 82/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 83/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2028
# Validation Accuracy: 0.2088
# Test Accuracy: 0.2108
#
# Combination 84/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2145
# Test Accuracy: 0.2006
#
# Combination 85/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.2138
# Test Accuracy: 0.2136
#
# Combination 86/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 87/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2006
# Validation Accuracy: 0.2251
# Test Accuracy: 0.1926
#
# Combination 88/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2186
# Validation Accuracy: 0.2102
# Test Accuracy: 0.2034
#
# Combination 89/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1886
#
# Combination 90/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2138
# Validation Accuracy: 0.2067
# Test Accuracy: 0.1903
#
# Combination 91/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2086
# Validation Accuracy: 0.2209
# Test Accuracy: 0.1852
#
# Combination 92/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2008
# Validation Accuracy: 0.1974
# Test Accuracy: 0.1864
#
# Combination 93/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.2081
# Test Accuracy: 0.2125
#
# Combination 94/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2006
# Validation Accuracy: 0.2180
# Test Accuracy: 0.2114
#
# Combination 95/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 96/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2090
# Validation Accuracy: 0.2223
# Test Accuracy: 0.1784
#
# Combination 97/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2045
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1960
#
# Combination 98/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 99/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2166
# Validation Accuracy: 0.2166
# Test Accuracy: 0.1909
#
# Combination 100/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2116
# Test Accuracy: 0.1972
#
# Validating feature: Customer_Care_Calls
#
# Training models for feature: Customer_Care_Calls
# Number of parameter combinations: 100
#
# Combination 1/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Accuracy: 0.1989
# Validation Accuracy: 0.2173
# Test Accuracy: 0.2074
#
# Combination 2/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2053
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1977
#
# Combination 3/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.2202
# Test Accuracy: 0.1949
#
# Combination 4/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2070
# Validation Accuracy: 0.2024
# Test Accuracy: 0.2091
#
# Combination 5/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.2216
# Test Accuracy: 0.1926
#
# Combination 6/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2008
# Validation Accuracy: 0.2074
# Test Accuracy: 0.1898
#
# Combination 7/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.2202
# Test Accuracy: 0.1949
#
# Combination 8/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 9/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2086
# Validation Accuracy: 0.2195
# Test Accuracy: 0.1852
#
# Combination 10/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1946
# Validation Accuracy: 0.1996
# Test Accuracy: 0.1937
#
# Combination 11/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2088
# Validation Accuracy: 0.2109
# Test Accuracy: 0.1841
#
# Combination 12/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2053
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1977
#
# Combination 13/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2060
# Validation Accuracy: 0.2173
# Test Accuracy: 0.1841
#
# Combination 14/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1949
#
# Combination 15/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 16/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.1980
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1977
#
# Combination 17/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2040
#
# Combination 18/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.1804
# Test Accuracy: 0.2074
#
# Combination 19/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.1999
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1960
#
# Combination 20/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1990
# Validation Accuracy: 0.2053
# Test Accuracy: 0.1943
#
# Combination 21/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.1948
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1926
#
# Combination 22/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 23/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 24/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2065
# Validation Accuracy: 0.1967
# Test Accuracy: 0.1972
#
# Combination 25/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.2053
# Test Accuracy: 0.2057
#
# Combination 26/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2060
# Validation Accuracy: 0.2088
# Test Accuracy: 0.1943
#
# Combination 27/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1983
#
# Combination 28/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 29/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2031
# Test Accuracy: 0.2023
#
# Combination 30/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2070
# Validation Accuracy: 0.2138
# Test Accuracy: 0.1864
#
# Combination 31/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2054
# Validation Accuracy: 0.2074
# Test Accuracy: 0.2068
#
# Combination 32/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2029
# Validation Accuracy: 0.1960
# Test Accuracy: 0.2017
#
# Combination 33/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2015
# Validation Accuracy: 0.1783
# Test Accuracy: 0.2062
#
# Combination 34/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2159
# Test Accuracy: 0.1966
#
# Combination 35/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2028
# Validation Accuracy: 0.2031
# Test Accuracy: 0.1869
#
# Combination 36/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2076
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1932
#
# Combination 37/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2042
# Validation Accuracy: 0.2095
# Test Accuracy: 0.1915
#
# Combination 38/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2095
# Validation Accuracy: 0.2195
# Test Accuracy: 0.1949
#
# Combination 39/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2069
# Validation Accuracy: 0.2223
# Test Accuracy: 0.1875
#
# Combination 40/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 41/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2012
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1869
#
# Combination 42/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2108
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1864
#
# Combination 43/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1999
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1960
#
# Combination 44/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.1987
# Validation Accuracy: 0.2124
# Test Accuracy: 0.2085
#
# Combination 45/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2099
# Validation Accuracy: 0.2202
# Test Accuracy: 0.1949
#
# Combination 46/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 47/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2058
# Validation Accuracy: 0.2173
# Test Accuracy: 0.1864
#
# Combination 48/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 49/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 50/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2051
# Validation Accuracy: 0.2067
# Test Accuracy: 0.2068
#
# Combination 51/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2056
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1835
#
# Combination 52/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1990
# Validation Accuracy: 0.2031
# Test Accuracy: 0.1915
#
# Combination 53/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2083
# Validation Accuracy: 0.2102
# Test Accuracy: 0.1881
#
# Combination 54/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1982
# Validation Accuracy: 0.1989
# Test Accuracy: 0.2006
#
# Combination 55/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2037
# Validation Accuracy: 0.2116
# Test Accuracy: 0.1892
#
# Combination 56/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 57/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2035
# Validation Accuracy: 0.2060
# Test Accuracy: 0.1858
#
# Combination 58/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2037
# Validation Accuracy: 0.1946
# Test Accuracy: 0.2159
#
# Combination 59/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2056
# Validation Accuracy: 0.1989
# Test Accuracy: 0.2034
#
# Combination 60/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2012
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1869
#
# Combination 61/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1949
#
# Combination 62/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.1989
# Validation Accuracy: 0.2038
# Test Accuracy: 0.2074
#
# Combination 63/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2033
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1892
#
# Combination 64/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2081
# Validation Accuracy: 0.2031
# Test Accuracy: 0.2062
#
# Combination 65/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2100
# Validation Accuracy: 0.2053
# Test Accuracy: 0.1960
#
# Combination 66/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.1989
# Validation Accuracy: 0.2017
# Test Accuracy: 0.1920
#
# Combination 67/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2069
# Validation Accuracy: 0.2116
# Test Accuracy: 0.1898
#
# Combination 68/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2047
# Validation Accuracy: 0.2180
# Test Accuracy: 0.1869
#
# Combination 69/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2045
# Validation Accuracy: 0.1911
# Test Accuracy: 0.1983
#
# Combination 70/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 16}
# Train Accuracy: 0.2063
# Validation Accuracy: 0.2244
# Test Accuracy: 0.1903
#
# Combination 71/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2074
# Validation Accuracy: 0.2216
# Test Accuracy: 0.1926
#
# Combination 72/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 73/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 74/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2061
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1898
#
# Combination 75/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2122
# Validation Accuracy: 0.2095
# Test Accuracy: 0.1932
#
# Combination 76/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 16}
# Train Accuracy: 0.2115
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1937
#
# Combination 77/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 78/100
# Parameters: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 79/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.1999
# Validation Accuracy: 0.2045
# Test Accuracy: 0.1966
#
# Combination 80/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2031
# Validation Accuracy: 0.2067
# Test Accuracy: 0.2017
#
# Combination 81/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2045
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2170
#
# Combination 82/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.1967
# Validation Accuracy: 0.1960
# Test Accuracy: 0.1949
#
# Combination 83/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.1, 'units': 32}
# Train Accuracy: 0.2005
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2062
#
# Combination 84/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.1992
# Validation Accuracy: 0.2024
# Test Accuracy: 0.2051
#
# Combination 85/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 86/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 32}
# Train Accuracy: 0.2065
# Validation Accuracy: 0.2138
# Test Accuracy: 0.2045
#
# Combination 87/100
# Parameters: {'activation': 'relu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2093
# Validation Accuracy: 0.2166
# Test Accuracy: 0.1875
#
# Combination 88/100
# Parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'learning_rate': 0.01, 'units': 128}
# Train Accuracy: 0.2038
# Validation Accuracy: 0.2124
# Test Accuracy: 0.1949
#
# Combination 89/100
# Parameters: {'activation': 'elu', 'batch_size': 32, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2026
# Validation Accuracy: 0.2131
# Test Accuracy: 0.1955
#
# Combination 90/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.1, 'learning_rate': 0.01, 'units': 16}
# Train Accuracy: 0.2054
# Validation Accuracy: 0.2074
# Test Accuracy: 0.2068
#
# Combination 91/100
# Parameters: {'activation': 'tanh', 'batch_size': 128, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2045
# Validation Accuracy: 0.2081
# Test Accuracy: 0.2142
#
# Combination 92/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 32}
# Train Accuracy: 0.2045
# Validation Accuracy: 0.2081
# Test Accuracy: 0.2142
#
# Combination 93/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.1, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 94/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.1957
# Validation Accuracy: 0.2031
# Test Accuracy: 0.2011
#
# Combination 95/100
# Parameters: {'activation': 'tanh', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.01, 'units': 64}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 96/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.1, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2090
# Validation Accuracy: 0.2024
# Test Accuracy: 0.1943
#
# Combination 97/100
# Parameters: {'activation': 'elu', 'batch_size': 64, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2053
# Validation Accuracy: 0.2145
# Test Accuracy: 0.1977
#
# Combination 98/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.2, 'learning_rate': 0.1, 'units': 128}
# Train Accuracy: 0.2072
# Validation Accuracy: 0.2188
# Test Accuracy: 0.1852
#
# Combination 99/100
# Parameters: {'activation': 'relu', 'batch_size': 64, 'dropout': 0.4, 'learning_rate': 0.001, 'units': 64}
# Train Accuracy: 0.2092
# Validation Accuracy: 0.2095
# Test Accuracy: 0.2040
#
# Combination 100/100
# Parameters: {'activation': 'elu', 'batch_size': 128, 'dropout': 0.3, 'learning_rate': 0.001, 'units': 128}
# Train Accuracy: 0.2049
# Validation Accuracy: 0.1939
# Test Accuracy: 0.2131
#
# Experiment completed!
# Results saved in directory: /content/gdrive/My Drive/Projects/CustomerSatisfactionLogistics/feature_validation_results_20250116_172935
#
# Feature Comparison Summary:
#                Feature  Mean Validation Accuracy  Max Validation Accuracy  \
# 0      Reached_on_Time                  0.206953                 0.218750
# 1  Cost_of_the_Product                  0.211825                 0.233665
# 2  Customer_Care_Calls                  0.209474                 0.224432
#
#    Min Validation Accuracy  Std Validation Accuracy
# 0                 0.186790                 0.007807
# 1                 0.183949                 0.009175
# 2                 0.178267                 0.008677
